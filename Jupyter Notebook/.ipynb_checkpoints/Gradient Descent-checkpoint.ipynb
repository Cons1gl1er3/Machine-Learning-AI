# %%
# import required libraries
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# To begin, we create some random data points using np.random.rand

# %%
X = np.random.rand(500,1)
# For simplify, assume the data is good for linear model
y = 3*X + 5 + 0.15*np.random.randn(500, 1) # Add noise
plt.plot(X, y, 'ro', markersize = 3)
plt.show()

# %%
# Build the gradient descent function
# The function take in X_bar, which is the matrix X add a ones vector at the back
class GradientDescent:
    def __init__(self, learning_rate):
        self.learning_rate = learning_rate

    def gradient(self, X, w):
        n = X.shape[0]
        return 1/N*X.T.dot(X.dot(w) - y)

    def cost(self, X, w):
        n = X.shape[0]
        return 0.5/n*np.linalg.norm(y-X.dot(w), 2)**2
